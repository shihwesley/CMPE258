# %%
##from google.colab import drive
##drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
##%cd /content/drive/MyDrive/Colab\ Notebooks/CMPE258
# Out:
# /content/drive/MyDrive/Colab Notebooks/CMPE258

# %%
##username = 'shihwesley'
##repository = 'CMPE258'

# %%
##!git config --global user.email "shih.wesley@gmail.com"
##!git config --global user.name "Wesley Shih"

# %%
##!git clone https://{git_token}@github.com/{username}/{repository}

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	Github_init.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add .

# %%
# !git commit -m "first push from colab to github"
# Out:
# [main 6e3b9db] first push from colab to github
#  1 file changed, 1 insertion(+)
#  create mode 100644 Github_init.ipynb

# %%
# !git push
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.58 KiB | 323.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/shihwesley/CMPE258
#    351849a..6e3b9db  main -> main

# %%
##!git config --list
