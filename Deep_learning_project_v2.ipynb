# %%
# !pip install super_gradients
# Out:
# Collecting super_gradients
#   Downloading super_gradients-3.1.1-py3-none-any.whl (964 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 964.2/964.2 kB 15.9 MB/s eta 0:00:00a 0:00:01
# Collecting opencv-python>=4.5.1
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 25.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: psutil>=5.8.0 in /home/codespace/.local/lib/python3.9/site-packages (from super_gradients) (5.9.4)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 60.4 MB/s eta 0:00:00:00:01
# Collecting hydra-core>=1.2.0
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.0 MB/s eta 0:00:00
# Collecting pyparsing==2.4.5
#   Downloading pyparsing-2.4.5-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 4.5 MB/s eta 0:00:00
# Collecting json-tricks==3.16.1
#   Downloading json_tricks-3.16.1-py2.py3-none-any.whl (27 kB)
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting boto3>=1.17.15
#   Downloading boto3-1.26.133-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 9.1 MB/s eta 0:00:00
# Collecting onnxruntime==1.13.1
#   Downloading onnxruntime-1.13.1-cp39-cp39-manylinux_2_27_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 63.2 MB/s eta 0:00:00:00:01
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (57.4.0)
# Requirement already satisfied: packaging>=20.4 in /home/codespace/.local/lib/python3.9/site-packages (from super_gradients) (23.0)
# Collecting omegaconf
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.38.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (0.40.0)
# Collecting protobuf==3.20.3
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.2.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (9.3.0)
# Collecting onnx-simplifier<1.0,>=0.3.6
#   Downloading onnx_simplifier-0.4.28-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 19.6 MB/s eta 0:00:0000:01:00:01
# Collecting Deprecated>=1.2.11
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting treelib==1.6.1
#   Downloading treelib-1.6.1.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Collecting coverage~=5.3.1
#   Downloading coverage-5.3.1-cp39-cp39-manylinux2010_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 14.4 MB/s eta 0:00:00
# Collecting sphinx~=4.0.2
#   Downloading Sphinx-4.0.3-py3-none-any.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 67.5 MB/s eta 0:00:00:00:01
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (1.10.1)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (2.12.1)
# Collecting torchmetrics==0.8
#   Downloading torchmetrics-0.8.0-py3-none-any.whl (408 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 408.6/408.6 kB 24.8 MB/s eta 0:00:00
# Collecting einops==0.3.2
#   Downloading einops-0.3.2-py3-none-any.whl (25 kB)
# Collecting numpy<=1.23
#   Downloading numpy-1.23.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 60.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (0.16.0.dev20230411+cpu)
# Collecting onnx==1.13.0
#   Downloading onnx-1.13.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 71.8 MB/s eta 0:00:0000:0100:01
# Collecting pip-tools>=6.12.1
#   Downloading pip_tools-6.13.0-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.5 MB/s eta 0:00:00
# Collecting stringcase>=1.2.0
#   Downloading stringcase-1.2.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tqdm>=4.57.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from super_gradients) (3.7.1)
# Collecting pycocotools==2.0.4
#   Downloading pycocotools-2.0.4.tar.gz (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 7.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jsonschema>=3.2.0
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 6.3 MB/s eta 0:00:00
# Collecting torch<1.14,>=1.9.0
#   Downloading torch-1.13.1-cp39-cp39-manylinux1_x86_64.whl (887.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 2.4 MB/s eta 0:00:0000:0100:01
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.0.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 72.3 MB/s eta 0:00:00:00:01
# Requirement already satisfied: pygments>=2.7.4 in /home/codespace/.local/lib/python3.9/site-packages (from super_gradients) (2.15.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from onnx==1.13.0->super_gradients) (4.4.0)
# Requirement already satisfied: sympy in /usr/local/python/3.9.7/lib/python3.9/site-packages (from onnxruntime==1.13.1->super_gradients) (1.11.1)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/python/3.9.7/lib/python3.9/site-packages (from onnxruntime==1.13.1->super_gradients) (23.3.3)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 36.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 5.3 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.133
#   Downloading botocore-1.29.133-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 94.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from Deprecated>=1.2.11->super_gradients) (1.14.1)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting attrs>=17.4.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 4.0 MB/s eta 0:00:00
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from matplotlib>=3.3.4->super_gradients) (5.12.0)
# Collecting PyYAML>=5.1.0
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 kB 30.4 MB/s eta 0:00:00
# Collecting rich
#   Downloading rich-13.3.5-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 15.6 MB/s eta 0:00:00
# Requirement already satisfied: pip>=22.2 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from pip-tools>=6.12.1->super_gradients) (23.0.1)
# Collecting build
#   Downloading build-0.10.0-py3-none-any.whl (17 kB)
# Collecting click>=8
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 6.5 MB/s eta 0:00:00
# Collecting sphinxcontrib-serializinghtml
#   Downloading sphinxcontrib_serializinghtml-1.1.5-py2.py3-none-any.whl (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 6.3 MB/s eta 0:00:00
# Collecting alabaster<0.8,>=0.7
#   Downloading alabaster-0.7.13-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests>=2.5.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from sphinx~=4.0.2->super_gradients) (2.28.1)
# Collecting sphinxcontrib-qthelp
#   Downloading sphinxcontrib_qthelp-1.0.3-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from sphinx~=4.0.2->super_gradients) (3.1.2)
# Collecting sphinxcontrib-devhelp
#   Downloading sphinxcontrib_devhelp-1.0.2-py2.py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.7/84.7 kB 5.9 MB/s eta 0:00:00
# Collecting imagesize
#   Downloading imagesize-1.4.1-py2.py3-none-any.whl (8.8 kB)
# Collecting docutils<0.18,>=0.14
#   Downloading docutils-0.17.1-py2.py3-none-any.whl (575 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 575.5/575.5 kB 27.7 MB/s eta 0:00:00
# Collecting sphinxcontrib-applehelp
#   Downloading sphinxcontrib_applehelp-1.0.4-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.6/120.6 kB 8.6 MB/s eta 0:00:00
# Collecting sphinxcontrib-htmlhelp
#   Downloading sphinxcontrib_htmlhelp-2.0.1-py3-none-any.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.8/99.8 kB 6.9 MB/s eta 0:00:00
# Collecting sphinxcontrib-jsmath
#   Downloading sphinxcontrib_jsmath-1.0.1-py2.py3-none-any.whl (5.1 kB)
# Collecting babel>=1.3
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 89.8 MB/s eta 0:00:0000:0100:01
# Collecting snowballstemmer>=1.1
#   Downloading snowballstemmer-2.2.0-py2.py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.0/93.0 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (2.17.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (3.4.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (1.53.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (1.4.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from tensorboard>=2.4.1->super_gradients) (2.2.3)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 35.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 57.0 MB/s eta 0:00:0000:0100:01
# Collecting torchvision>=0.10.0
#   Downloading torchvision-0.15.2-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 72.0 MB/s eta 0:00:00:00:0100:01
#   Downloading torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 84.3 MB/s eta 0:00:00:00:01
#   Downloading torchvision-0.14.1-cp39-cp39-manylinux1_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 46.8 MB/s eta 0:00:0000:0100:01
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from botocore<1.30.0,>=1.29.133->boto3>=1.17.15->super_gradients) (1.26.13)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super_gradients) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super_gradients) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super_gradients) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /home/codespace/.local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->super_gradients) (1.16.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->super_gradients) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/codespace/.local/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.4->super_gradients) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from Jinja2>=2.3->sphinx~=4.0.2->super_gradients) (2.1.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/codespace/.local/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard>=2.4.1->super_gradients) (6.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super_gradients) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super_gradients) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from requests>=2.5.0->sphinx~=4.0.2->super_gradients) (2022.12.7)
# Collecting pyproject_hooks
#   Downloading pyproject_hooks-1.0.0-py3-none-any.whl (9.3 kB)
# Collecting tomli>=1.1.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.3 MB/s eta 0:00:00
# Collecting markdown-it-py<3.0.0,>=2.2.0
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from sympy->onnxruntime==1.13.1->super_gradients) (1.2.1)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->super_gradients) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/python/3.9.7/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->super_gradients) (3.2.2)
# Building wheels for collected packages: pycocotools, termcolor, treelib, antlr4-python3-runtime, stringcase, future
#   Building wheel for pycocotools (pyproject.toml) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.4-cp39-cp39-linux_x86_64.whl size=401127 sha256=93af62429e2826bfc0031109911353d17fe5f2a08dbd87e740ae6e7f2cdc3904
#   Stored in directory: /home/codespace/.cache/pip/wheels/7e/b0/8e/f2c3593944ead79f5146d057d1310ee6d7b60d30b826779846
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4848 sha256=87cb53e330c48d397b268f740205a1ae0a2a9e8aa72fd9637a4c76845a572531
#   Stored in directory: /home/codespace/.cache/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
#   Building wheel for treelib (setup.py) ... done
#   Created wheel for treelib: filename=treelib-1.6.1-py3-none-any.whl size=18384 sha256=781346b11ee446ac3039f957a8d5274d50a493966b0ef9306dce690e6e38f566
#   Stored in directory: /home/codespace/.cache/pip/wheels/43/de/32/fd270cc5f06de2bebcdaa666e9350b95f54d983212a7aba9ad
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144574 sha256=31984f7736f34aef1953af5c2ace5b23f70fc3f78d6219940e686f2bbccdcda6
#   Stored in directory: /home/codespace/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3588 sha256=293e0351b3721146f642f434e9ba87c2b32e9275f3122a4306fec02d7f41f218
#   Stored in directory: /home/codespace/.cache/pip/wheels/0a/0d/86/88baa0554de5fdccfc2b2ee060175eec0a85c12cdfd8fef566
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492035 sha256=c3104f5adc95d1a33a4c42efac156fef67123486ab8e02066f5bcff0d434a559
#   Stored in directory: /home/codespace/.cache/pip/wheels/bf/5d/6a/2e53874f7ec4e2bede522385439531fafec8fafe005b5c3d1b
# Successfully built pycocotools termcolor treelib antlr4-python3-runtime stringcase future
# Installing collected packages: termcolor, stringcase, snowballstemmer, json-tricks, einops, antlr4-python3-runtime, tqdm, tomli, sphinxcontrib-serializinghtml, sphinxcontrib-qthelp, sphinxcontrib-jsmath, sphinxcontrib-htmlhelp, sphinxcontrib-devhelp, sphinxcontrib-applehelp, rapidfuzz, PyYAML, pyrsistent, pyparsing, pyDeprecate, protobuf, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, mdurl, jmespath, imagesize, humanfriendly, future, docutils, Deprecated, coverage, click, babel, attrs, alabaster, treelib, sphinx, pyproject_hooks, opencv-python, onnx, omegaconf, nvidia-cudnn-cu11, markdown-it-py, jsonschema, coloredlogs, botocore, torch, sphinxcontrib-jquery, s3transfer, rich, onnxruntime, hydra-core, build, torchvision, torchmetrics, sphinx-rtd-theme, pycocotools, pip-tools, onnx-simplifier, boto3, super_gradients
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.2.0
#     Uninstalling termcolor-2.2.0:
#       Successfully uninstalled termcolor-2.2.0
#   WARNING: The script tqdm is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.22.1
#     Uninstalling protobuf-4.22.1:
#       Successfully uninstalled protobuf-4.22.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.5
#     Uninstalling numpy-1.23.5:
#       Successfully uninstalled numpy-1.23.5
#   WARNING: The scripts f2py, f2py3 and f2py3.9 are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script humanfriendly is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts futurize and pasteurize are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts coverage, coverage-3.9 and coverage3 are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pybabel is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts sphinx-apidoc, sphinx-autogen, sphinx-build and sphinx-quickstart are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts backend-test-tools, check-model and check-node are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script markdown-it is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script jsonschema is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script coloredlogs is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0.dev20230411+cpu
#     Uninstalling torch-2.1.0.dev20230411+cpu:
#       Successfully uninstalled torch-2.1.0.dev20230411+cpu
#   WARNING: The scripts convert-caffe2-to-onnx, convert-onnx-to-caffe2 and torchrun are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script onnxruntime_test is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pyproject-build is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.16.0.dev20230411+cpu
#     Uninstalling torchvision-0.16.0.dev20230411+cpu:
#       Successfully uninstalled torchvision-0.16.0.dev20230411+cpu
#   WARNING: The scripts pip-compile and pip-sync are installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script onnxsim is installed in '/usr/local/python/3.9.7/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0.dev20230411+cpu requires torch==2.1.0.dev20230411, but you have torch 1.13.1 which is incompatible.
# Successfully installed Deprecated-1.2.13 PyYAML-6.0 alabaster-0.7.13 antlr4-python3-runtime-4.9.3 attrs-23.1.0 babel-2.12.1 boto3-1.26.133 botocore-1.29.133 build-0.10.0 click-8.1.3 coloredlogs-15.0.1 coverage-5.3.1 docutils-0.17.1 einops-0.3.2 future-0.18.3 humanfriendly-10.0 hydra-core-1.3.2 imagesize-1.4.1 jmespath-1.0.1 json-tricks-3.16.1 jsonschema-4.17.3 markdown-it-py-2.2.0 mdurl-0.1.2 numpy-1.23.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 omegaconf-2.3.0 onnx-1.13.0 onnx-simplifier-0.4.28 onnxruntime-1.13.1 opencv-python-4.7.0.72 pip-tools-6.13.0 protobuf-3.20.3 pyDeprecate-0.3.2 pycocotools-2.0.4 pyparsing-2.4.5 pyproject_hooks-1.0.0 pyrsistent-0.19.3 rapidfuzz-3.0.0 rich-13.3.5 s3transfer-0.6.1 snowballstemmer-2.2.0 sphinx-4.0.3 sphinx-rtd-theme-1.2.0 sphinxcontrib-applehelp-1.0.4 sphinxcontrib-devhelp-1.0.2 sphinxcontrib-htmlhelp-2.0.1 sphinxcontrib-jquery-4.1 sphinxcontrib-jsmath-1.0.1 sphinxcontrib-qthelp-1.0.3 sphinxcontrib-serializinghtml-1.1.5 stringcase-1.2.0 super_gradients-3.1.1 termcolor-1.1.0 tomli-2.0.1 torch-1.13.1 torchmetrics-0.8.0 torchvision-0.14.1 tqdm-4.65.0 treelib-1.6.1
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python -m pip install --upgrade pip

# %%
from super_gradients.training import models
from super_gradients.common.object_names import Models

yolo_nas = models.get("yolo_nas_s", pretrained_weights="coco")
yolo_nas.predict("https://deci-pretrained-models.s3.amazonaws.com/sample_images/beatles-abbeyroad.jpg").show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from super_gradients.training import models
#       2 from super_gradients.common.object_names import Models
#       4 yolo_nas = models.get("yolo_nas_s", pretrained_weights="coco")
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/__init__.py:2
#       1 from super_gradients.common import init_trainer, is_distributed, object_names
# ----> 2 from super_gradients.training import losses, utils, datasets_utils, DataAugmentation, Trainer, KDTrainer, QATTrainer
#       3 from super_gradients.common.registry.registry import ARCHITECTURES
#       4 from super_gradients.sanity_check import env_sanity_check
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/training/__init__.py:2
#       1 # PACKAGE IMPORTS FOR EXTERNAL USAGE
# ----> 2 import super_gradients.training.utils.distributed_training_utils as distributed_training_utils
#       3 from super_gradients.training.datasets import datasets_utils, DataAugmentation
#       4 from super_gradients.training.sg_trainer import Trainer
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/training/utils/__init__.py:5
#       3 from super_gradients.training.utils.version_utils import torch_version_is_greater_or_equal
#       4 from super_gradients.training.utils.config_utils import raise_if_unused_params, warn_if_unused_params
# ----> 5 from super_gradients.training.utils.early_stopping import EarlyStop
#       6 from super_gradients.training.utils.pose_estimation import DEKRPoseEstimationDecodeCallback, DEKRVisualizationCallback
#       8 __all__ = [
#       9     "Timer",
#      10     "HpmStruct",
#    (...)
#      23     "DEKRVisualizationCallback",
#      24 ]
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/training/utils/early_stopping.py:1
# ----> 1 from super_gradients.training.utils.callbacks import PhaseCallback, Phase, PhaseContext
#       2 from typing import Optional
#       3 import torch
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/training/utils/callbacks/__init__.py:2
#       1 from super_gradients.training.utils.callbacks.base_callbacks import CallbackHandler, PhaseCallback, Callback, PhaseContext, Phase
# ----> 2 from super_gradients.training.utils.callbacks.callbacks import (
#       3     ContextSgMethods,
#       4     ModelConversionCheckCallback,
#       5     DeciLabUploadCallback,
#       6     LRCallbackBase,
#       7     EpochStepWarmupLRCallback,
#       8     BatchStepLinearWarmupLRCallback,
#       9     StepLRCallback,
#      10     ExponentialLRCallback,
#      11     PolyLRCallback,
#      12     CosineLRCallback,
#      13     FunctionLRCallback,
#      14     IllegalLRSchedulerMetric,
#      15     LRSchedulerCallback,
#      16     MetricsUpdateCallback,
#      17     KDModelMetricsUpdateCallback,
#      18     PhaseContextTestCallback,
#      19     DetectionVisualizationCallback,
#      20     BinarySegmentationVisualizationCallback,
#      21     TrainingStageSwitchCallbackBase,
#      22     YoloXTrainingStageSwitchCallback,
#      23     TestLRCallback,
#      24 )
#      25 from super_gradients.training.utils.callbacks.ppyoloe_switch_callback import PPYoloETrainingStageSwitchCallback
#      26 from super_gradients.common.object_names import Callbacks, LRSchedulers, LRWarmups
#
# File ~/.python/current/lib/python3.9/site-packages/super_gradients/training/utils/callbacks/callbacks.py:9
#       6 from typing import List, Union, Optional
#       8 import csv
# ----> 9 import cv2
#      10 import numpy as np
#      11 import onnx
#
# ImportError: libGL.so.1: cannot open shared object file: No such file or directory
